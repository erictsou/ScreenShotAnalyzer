# %%
import cv2
import numpy as np
from  matplotlib import pyplot as plt
from imp import reload 
import sys
import os
import concurrent.futures

# %%
def getDictInfo(element, test_tag, cnt, dictInfo):
    if (True in (element['tag'] == a for a in test_tag)) or (True in (a in element['tag'] for a in test_tag)):
        x = int(element['x'])
        y = int(element['y'])
        w = int(element['width'])
        h = int(element['height'])
        dictInfo.append([x,y,w,h])
        
        
def analyzeDict(img, test_tag):
    dictInfo=[]
    img_test = img.copy()
    ##94 elements
    cnt = 0
    for i in hierarchy_dict:
        cnt+=1
        print('i:',i["tag"], cnt)
        if "_EA@text" in i: print(i["_EA@text"], cnt)
        getDictInfo(i, test_tag, cnt, dictInfo)

        for j in i['child']:
            cnt+=1
            print('j:',j["tag"], cnt)
            if "_EA@text" in j: print(j["_EA@text"], cnt)
            getDictInfo(j, test_tag, cnt, dictInfo)

            for k in j['child']:
                cnt+=1
                print('k:',k["tag"], cnt)
                if "_EA@text" in k: print(k["_EA@text"], cnt)
                getDictInfo(k, test_tag, cnt, dictInfo)

                for l in k['child']:
                    cnt+=1
                    print('l:',l["tag"], cnt)
                    if "_EA@text" in l: print(l["_EA@text"], cnt)
                    getDictInfo(l, test_tag, cnt, dictInfo)

                    for m in l['child']:
                        cnt+=1
                        print('m:',m["tag"], cnt)
                        if "_EA@text" in m: print(m["_EA@text"], cnt)
                        getDictInfo(m, test_tag, cnt, dictInfo)

                        for n in m['child']:
                            cnt+=1
                            print('n:',n["tag"], cnt)
                            if "_EA@text" in n: print(n["_EA@text"], cnt)
                            getDictInfo(n, test_tag, cnt, dictInfo)

                            for o in n['child']:
                                cnt+=1
                                print('o:',o["tag"], cnt)
                                if "_EA@text" in o: print(o["_EA@text"], cnt)
                                getDictInfo(o, test_tag, cnt, dictInfo)



    print('total element num:', cnt)
    
    return dictInfo

# %%
##analyze taad dumped dict and experiment

##目前state dict有重複的：mail, spotify, messenger, chrome, pchome
import json
from allProcess import *
reload(sys.modules['allProcess'])
from allProcess import *

IMG_LIST = [1]
IMG_NUM = 6


# print('===========PROCESSING IMAGE NUMBER '+str(IMG_NUM)+'=============')

    
with open('./experiment/'+str(IMG_NUM)+'.json', 'r') as fp:
#with open('./experiment/data.json', 'r') as fp:
    j = json.load(fp)
hierarchy_dict = j['child']

img = cv2.imread('./experiment/'+str(IMG_NUM)+'.png', 1)
#img = cv2.imread('./experiment/currentScreenshot.png', 1)
height,width,_ = img.shape
print('shape:', height,width)
test_tag=['button','img']


dictInfo = analyzeDict(img, test_tag)
contours = allProcess(str(IMG_NUM), True)

##去掉contours和dictInfo重疊的部分
for d in dictInfo.copy():
    for c in contours:
        if d == c[1]:
            dictInfo.remove(d)

contourInfo = [c for c in contours if c[1][1]+c[1][3]>95]
#implement experiment設為true
##刪掉時間和電池圖示
# Out:
# shape: 2436 1125
# i: div 1
# j: div 2
# k: div 3
# l: div 4
# l: div 5
# m: div 6
# m: div 7
# n: div 8
# n: div 9
# l: div 10
# m: ['ul', 'div'] 11
# n: div 12
# o: div 13
# 午安 13
# o: div 14
# n: div 15
# o: div 16
# o: ul 17
# n: ['div', 'button'] 18
# 與下列藝人風格相似的藝人： Oasis 18
# n: ['ul', 'div'] 19
# o: ['button', 'div'] 20
# Best of Rock: 1995 Queen, Red Hot Chili Peppers, Radiohead, Supergrass, AC/DC 20
# o: ['button', 'div'] 21
# Garage Rock Revival The Strokes, Supergrass, Arctic Monkeys, The Killers 21
# o: ['button', 'div'] 22
# Oasis 電台 The Killers, Oasis, The Smiths, Keane, Snow Patrol 22
# n: ['div', 'button'] 23
# 你可能會喜歡的節目 23
# n: ['ul', 'div'] 24
# o: ['button', 'div'] 25
# 老高與小茉 Mr & Mrs Gao Gao Lao 25
# o: ['button', 'div'] 26
# 耳朵借我 馬世芳 26
# o: ['button', 'div'] 27
# 郭德纲于谦相声专辑 xiasong0_0 27
# n: div 28
# 垂直捲軸, 10頁 28
# n: div 29
# 水平捲軸, 1頁 29
# m: ol 30
# n: li 31
# o: button 32
# 14:44 32
# o: button 33
# 4G 33
# n: li 34
# o: button 35
# Fe 35
# o: button 36
# o: button 37
# n: li 38
# o: button 39
# JoJo'sBizarre Playlist:Battl... 39
# o: button 40
# n: li 41
# o: button 42
# LIAM GALLAGHER.... 42
# o: button 43
# ReleaseRadar 43
# n: li 44
# o: button 45
# 落日飛車 45
# o: button 46
# Jubilee 46
# n: ['button', 'li'] 47
# Oasis 47
# n: li 48
# o: button 49
# o: button 50
# o: button 51
# n: ['button', 'li'] 52
# The 52
# n: li 53
# o: button 54
# Snow 54
# o: button 55
# Peppers, 55
# n: li 56
# o: button 57
# Stand By Me 57
# o: button 58
# Oasis 58
# o: button 59
# L[6] 59
# o: button 60
# > 60
# m: ol 61
# n: li 62
# o: button 63
# 14:44 63
# o: button 64
# 4G 64
# n: li 65
# o: button 66
# Fe 66
# o: button 67
# o: button 68
# n: li 69
# o: button 70
# JoJo'sBizarre Playlist:Battl... 70
# o: button 71
# n: li 72
# o: button 73
# LIAM GALLAGHER.... 73
# o: button 74
# ReleaseRadar 74
# n: li 75
# o: button 76
# 落日飛車 76
# o: button 77
# Jubilee 77
# n: ['button', 'li'] 78
# Oasis 78
# n: li 79
# o: button 80
# o: button 81
# o: button 82
# n: ['button', 'li'] 83
# The 83
# n: li 84
# o: button 85
# Snow 85
# o: button 86
# Peppers, 86
# n: li 87
# o: button 88
# Stand By Me 88
# o: button 89
# Oasis 89
# o: button 90
# L[6] 90
# o: button 91
# > 91
# k: div 92
# 標籤列 92
# l: button 93
# 首頁 93
# l: button 94
# 搜尋 94
# l: button 95
# 你的音樂庫 95
# j: div 96
# k: ['XCUIElementTypeSlider', 'div'] 97
# 歌曲位置 97
# k: div 98
# k: div 99
# l: ['XCUIElementTypeImage', 'div'] 100
# l: div 101
# m: ['div', 'ul'] 102
# Stand By Me Oasis 102
# m: button 103
# 連接至裝置 103
# m: button 104
# 播放 104
# l: div 105
# i: ol 106
# j: li 107
# k: button 108
# 14:44 108
# k: button 109
# 4G 109
# j: li 110
# k: button 111
# Fe 111
# k: button 112
# k: button 113
# j: li 114
# k: button 115
# JoJo'sBizarre Playlist:Battl... 115
# k: button 116
# j: li 117
# k: button 118
# LIAM GALLAGHER.... 118
# k: button 119
# ReleaseRadar 119
# j: li 120
# k: button 121
# 落日飛車 121
# k: button 122
# Jubilee 122
# j: ['button', 'li'] 123
# Oasis 123
# j: li 124
# k: button 125
# k: button 126
# k: button 127
# j: ['button', 'li'] 128
# The 128
# j: li 129
# k: button 130
# Snow 130
# k: button 131
# Peppers, 131
# j: li 132
# k: button 133
# Stand By Me 133
# k: button 134
# Oasis 134
# k: button 135
# L[6] 135
# k: button 136
# > 136
# j: li 137
# k: button 138
# 首頁 138
# k: button 139
# 搜尋 139
# k: button 140
# 你的音樂庫 140
# i: ol 141
# j: li 142
# k: button 143
# 14:44 143
# k: button 144
# 4G 144
# j: li 145
# k: button 146
# Fe 146
# k: button 147
# k: button 148
# j: li 149
# k: button 150
# JoJo'sBizarre Playlist:Battl... 150
# k: button 151
# j: li 152
# k: button 153
# LIAM GALLAGHER.... 153
# k: button 154
# ReleaseRadar 154
# j: li 155
# k: button 156
# 落日飛車 156
# k: button 157
# Jubilee 157
# j: ['button', 'li'] 158
# Oasis 158
# j: li 159
# k: button 160
# k: button 161
# k: button 162
# j: ['button', 'li'] 163
# The 163
# j: li 164
# k: button 165
# Snow 165
# k: button 166
# Peppers, 166
# j: li 167
# k: button 168
# Stand By Me 168
# k: button 169
# Oasis 169
# k: button 170
# L[6] 170
# k: button 171
# > 171
# j: li 172
# k: button 173
# 首頁 173
# k: button 174
# 搜尋 174
# k: button 175
# 你的音樂庫 175
# total element num: 175
# image size:  2436 * 1125
# lowThreshold, highThreshold, mean: 13 27 135.92402152891808
# canny mean: 8.753650793650793
# canny mean after dilate by 5 : 64.91422550629447
# number of contour result: 237
# number of contours after filted by hierarchy: 81
# number of contours after filted by size: 80
# number of contours after filted out img noises: 64
# Logical Processors:  8
# get text thickerround[0]Box[0]thread[5]: x=526, y=2202, w=68, h=72, confidence: 93, text: Q
# [9, [11, 7, 10, -1]]
# round[0]Box[0]thread[7]: x=904, y=2208, w=15, h=66, confidence: 0, text:  [6, [7, 5, -1, -1]]
# round[0]Box[0]thread[7]: x=1017, y=2075, w=57, h=62, confidence: 93, text: > [13, [15, 11, 14, -1]]
# round[0]Box[0]thread[5]: x=194, y=2113, w=104, h=40, confidence: 96, text: Oasis [11, [13, 9, 12, -1]]
# round[0]Box[0]thread[5]: x=360, y=2058, w=64, h=39, confidence: 96, text: Me [17, [18, 15, -1, -1]]
# round[0]Box[0]thread[5]: x=307, y=2057, w=50, h=48, confidence: 97, text: By [18, [19, 17, -1, -1]]
# round[0]Box[0]thread[5]: x=194, y=2057, w=108, h=40, confidence: 96, text: Stand [19, [20, 18, -1, -1]]
# round[0]Box[0]thread[1]: x=525, y=2289, w=74, h=42, confidence: 96, text: 搜尋 [3, [4, 2, -1, -1]]
# round[0]Box[0]thread[3]: x=150, y=2289, w=74, h=42, confidence: 96, text: 首頁 [4, [5, 3, -1, -1]]
# round[0]Box[0]thread[3]: x=1040, y=1780, w=85, h=40, confidence: 92, text: Arctround[0]Box[0]thread[6]: x=154, y=2203, w=65, h=71, confidence: 76, text: aA  [7, [9, 6, 8, -1]][32, [33, 31, -1, -1]]
#
# round[0]Box[0]thread[6]: x=911, y=1780, w=86, h=40, confidence: 94, text: Su... [33, [34, 32, -1, -1]]
# round[0]Box[0]thread[1]: x=185, y=1781, w=125, h=45, confidence: 96, text: Keane, [31, [32, 20, -1, -1]]
# round[0]Box[0]thread[7]: x=855, y=2073, w=78, h=63, confidence: 71, text: L[6]round[0]Box[0]thread[3]: x=707, y=1780, w=202, h=46, confidence: 93, text: Radiohead,  [34, [35, 33, -1, -1]][15, [17, 13, 16, -1]]
# get text thicker
#
# round[0]Box[0]thread[3]: x=922, y=2208, w=48, h=66, confidence: 55, text: \ [5, [6, 4, -1, -1]]
# round[0]Box[0]thread[6]: x=544, y=1780, w=159, h=47, confidence: 96, text: Peppers, [35, [36, 34, -1, -1]]
# get text thicker
# round[0]Box[0]thread[4]: x=1116, y=1729, w=9, h=33, confidence: 0, text:  [39, [40, 38, -1, -1]]
# round[0]Box[0]thread[7]: x=312, y=1780, w=107, h=40, confidence: 96, text: Snow [37, [38, 36, -1, -1]]
# round[0]Box[0]thread[3]: x=759, y=1726, w=71, h=39, confidence: 95, text: Hotround[0]Box[0]thread[4]: x=1039, y=1725, w=75, h=40, confidence: 96, text: The  [41, [42, 40, -1, -1]]
# [40, [41, 39, -1, -1]]round[0]Box[0]thread[7]: x=832, y=1725, w=87, h=40, confidence: 96, text: Chili
#  [42, [44, 41, 43, -1]]
# round[0]Box[0]thread[3]: x=682, y=1725, w=72, h=40, confidence: 95, text: Redround[0]Box[0]thread[4]: x=363, y=1725, w=75, h=40, confidence: 96, text: The [44, [45, 42, -1, -1]]
#  [47, [48, 45, -1, -1]]
# round[0]Box[0]thread[6]: x=44, y=1780, w=136, h=46, confidence: 96, text: Smiths, [38, [39, 37, -1, -1]]
# round[0]Box[0]thread[6]: x=43, y=1725, w=75, h=40, confidence: 96, text: The [51, [52, 50, -1, -1]]
# round[0]Box[0]thread[7]: x=542, y=1725, w=135, h=46, confidence: 96, text: Queen, [45, [47, 44, 46, -1]]
# round[0]Box[0]thread[4]: x=248, y=1725, w=115, h=46, confidence: 96, text: Oasis,round[0]Box[0]thread[3]: x=122, y=1725, w=124, h=46, confidence: 96, text: Killers, [48, [50, 47, 49, -1]]
#  [50, [51, 48, -1, -1]]
# round[0]Box[0]thread[2]: x=851, y=2289, w=173, h=42, confidence: 94, text: 你的音樂庫 [2, [3, 0, -1, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=918, y=1630, w=66, h=54, confidence: 37, text: ‘ [73, [75, 72, 74, 66]]
# get text thicker
# round[0]Box[0]thread[7]: x=1037, y=1233, w=88, h=324, confidence: 1, text: , [57, [66, 56, 58, -1]]
# get text thicker
# round[0]Box[0]thread[1]: x=786, y=1588, w=93, h=96, confidence: 0, text: y [75, [77, 73, 76, 66]]
# get text thicker
# round[0]Box[0]thread[2]: x=422, y=1780, w=61, h=40, confidence: 81, text: P... [36, [37, 35, -1, -1]]
# round[0]Box[0]thread[2]: x=212, y=1105, w=177, h=64, confidence: 96, text: Oasis [137, [139, 98, 138, -1]]
# get text thicker
# round[0]Box[0]thread[2]: x=583, y=1054, w=16, h=26, confidence: 0, text:  [139, [140, 137, -1, -1]]
# get text thicker
# round[0]Box[0]thread[6]: x=1038, y=1634, w=87, h=61, confidence: 61, text: Lid [52, [55, 51, 53, -1]]
# get text thicker
# round[0]Box[0]thread[6]: x=43, y=1032, w=154, h=154, confidence: 0, text: HT [141, [151, 140, 142, -1]]
# round[0]Box[0]thread[2]: x=213, y=1047, w=367, h=40, confidence: 92, text: 與下列藝人風格相似的藝人 [140, [141, 139, -1, -1]]
# round[0]Box[0]thread[2]: x=744, y=766, w=328, h=160, confidence: 96, text: Jubilee [157, [159, 156, 158, 151]]
# get text thinner
# round[0]Box[0]thread[6]: x=567, y=756, w=516, h=180, confidence: 88, text: EaJubilee [151, [162, 141, 152, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=550, y=1243, w=441, h=441, confidence: 68, text: BestofRock 1995 加、 [93, [-1, 92, 94, 66]]
# round[0]Box[0]thread[6]: x=217, y=766, w=330, h=159, confidence: 94, text: 落日飛車 [179, [182, 178, 180, 162]]
# get text thicker
# round[0]Box[0]thread[7]: x=42, y=1233, w=462, h=462, confidence: 22, text: 99m [98, [137, 66, 99, -1]]
# round[0]Box[0]thread[6]: x=744, y=574, w=328, h=159, confidence: 95, text: ReleaseRadar [188, [-1, 187, 189, 183]]
# get text thicker
# round[0]Box[0]thread[4]: x=540, y=1233, w=463, h=462, confidence: 67, text: BestofRock 1995 .iN )%, [66, [98, 57, 67, -1]]
# round[0]Box[0]thread[6]: x=219, y=574, w=329, h=159, confidence: 79, text: LIAM GALLAGHER.... [198, [201, 197, 199, 191]]
# get text thicker
# round[0]Box[0]thread[2]: x=42, y=756, w=515, h=180, confidence: 50, text: 全sm [162, [183, 151, 163, -1]]
# get text thicker
# round[0]Box[0]thread[1]: x=52, y=1243, w=442, h=259, confidence: 52, text: fPeaAa. [133, [134, 132, -1, 98]]
# round[0]Box[0]thread[7]: x=42, y=564, w=516, h=181, confidence: 78, text: ohLIAM LikGALLAGHER.... GALLAGHER [191, [202, 183, 192, -1]]
# get text thicker
# round[0]Box[0]thread[7]: x=874, y=244, w=72, h=70, confidence: 59, text: ) [224, [227, 214, 225, -1]]
# get text thicker
# round[0]Box[0]thread[7]: x=1005, y=243, w=72, h=72, confidence: 59, text: 202 [227, [229, 224, 228, -1]]
# get text thinner
# round[0]Box[0]thread[0]: x=357, y=2391, w=412, h=26, confidence: 25, text: CY [0, [2, -1, 1, -1]]
# round[0]Box[0]thread[0]: x=943, y=51, w=56, h=38, confidence: 95, text: 4G [232, [233, 229, -1, -1]]
# round[0]Box[0]thread[1]: x=219, y=382, w=328, h=160, confidence: 92, text: JoJo'sBizarre Playlist:Battl... [219, [-1, 218, 220, 214]]
# round[0]Box[0]thread[0]: x=75, y=48, w=130, h=42, confidence: 95, text: 14:44get text thicker
# round[0]Box[0]thread[1]: x=877, y=47, w=62, h=43, confidence: 0, text:  [234, [235, 233, -1, -1]]
#  [233, [234, 232, -1, -1]]
# get text thicker
# round[0]Box[0]thread[6]: x=636, y=382, w=436, h=160, confidence: 68, text: nt集體制中 [212, [-1, 211, 213, 204]]
# get text thinner
# round[0]Box[0]thread[0]: x=47, y=237, w=147, h=78, confidence: 74, text: Fe [229, [232, 227, 230, -1]]
# get text thicker
# round[0]Box[0]thread[5]: x=1003, y=46, w=85, h=46, confidence: 51, text: eG [235, [-1, 234, 236, -1]]
# get text thinner
# round[0]Box[0]thread[6]: x=0, y=1995, w=1125, h=197, confidence: 56, text: .nStandByMece oggOasisL圖> [20, [31, 19, 21, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=567, y=564, w=516, h=181, confidence: 50, text: “™ReleaseRadar Po Reade才 [183, [191, 162, 184, -1]]
# get text thicker
# round[0]Box[0]thread[1]: x=567, y=372, w=516, h=181, confidence: 57, text: .corel集體制踢 .oeys“1 [204, [214, 203, 205, -1]]
# get text thicker
# round[0]Box[0]thread[4]: x=41, y=371, w=517, h=181, confidence: 76, text: 4JoJo'sBizarre ee)Playlist:Battl... [214, [224, 204, 215, -1]]
# took tot: 6.96446418762207
# remove [[20, [31, 19, 21, -1]], [0, 1995, 1125, 197], ['.nStandByMece oggOasisL圖>', 56]]
# before combine:  64
# after combine1:  33
# after combine2:  25
# after combine3:  25
# 25
# 234 [235, 233, -1, -1] [877, 46, 211, 46]
# text:  ['4G', 95]
# 233 [234, 232, -1, -1] [75, 48, 130, 42]
# text:  ['14:44', 95]
# 229 [232, 227, 230, -1] [47, 237, 147, 78]
# text:  ['Fe', 74]
# 227 [229, 224, 228, -1] [1005, 243, 72, 72]
# 224 [227, 214, 225, -1] [874, 244, 72, 70]
# 214 [224, 204, 215, -1] [41, 371, 517, 181]
# text:  ["JoJo'sBizarre Playlist:Battl...", 92]
# 204 [214, 203, 205, -1] [567, 372, 516, 181]
# 191 [202, 183, 192, -1] [42, 564, 516, 181]
# text:  ['LIAM GALLAGHER....', 79]
# 183 [191, 162, 184, -1] [567, 564, 516, 181]
# text:  ['ReleaseRadar', 95]
# 162 [183, 151, 163, -1] [42, 756, 515, 180]
# text:  ['落日飛車', 94]
# 151 [162, 141, 152, -1] [567, 756, 516, 180]
# text:  ['Jubilee', 96]
# 137 [139, 98, 138, -1] [43, 1032, 556, 154]
# text:  ['Oasis', 96]
# 98 [137, 66, 99, -1] [42, 1233, 462, 462]
# 66 [98, 57, 67, -1] [540, 1233, 463, 462]
# 73 [75, 72, 74, 66] [786, 1588, 198, 96] 2nd
# 73 [75, 72, 74, 66] [786, 1588, 198, 96]
# 57 [66, 56, 58, -1] [1037, 1233, 88, 324]
# 35 [36, 34, -1, -1] [542, 1634, 583, 192]
# text:  ['The Peppers,', 96]
# 37 [38, 36, -1, -1] [43, 1725, 440, 95]
# text:  ['Snow', 96]
# 17 [18, 15, -1, -1] [194, 2057, 230, 48]
# text:  ['Stand By Me', 96]
# 15 [17, 13, 16, -1] [855, 2073, 78, 63]
# text:  ['L[6]', 71]
# 13 [15, 11, 14, -1] [1017, 2075, 57, 62]
# text:  ['>', 93]
# 11 [13, 9, 12, -1] [194, 2113, 104, 40]
# text:  ['Oasis', 96]
# 3 [4, 2, -1, -1] [525, 2202, 74, 129]
# text:  ['搜尋', 96]
# 4 [5, 3, -1, -1] [150, 2203, 74, 128]
# text:  ['首頁', 96]
# 2 [3, 0, -1, -1] [851, 2208, 173, 123]
# text:  ['你的音樂庫', 94]
# cnt:  26
# temp length:  26

# %%
print(dictInfo)
print(contourInfo)

clone = img.copy()
for i,c in enumerate(contourInfo):
    x,y,w,h = c[1]
    cv2.rectangle(clone, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(clone, str(c[0][0]), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
cv2.imwrite('experiment/processed_'+str(IMG_NUM)+'.jpg', clone)
plt.figure(figsize=(50,25))
clone = cv2.cvtColor(clone, cv2.COLOR_BGR2RGB)
plt.imshow(clone)

img_test = img.copy()
for i,d in enumerate(dictInfo):
    x,y,w,h = d
    cv2.rectangle(img_test, (x, y), (x + w, y + h), (0, 255, 0), 2)
    #cv2.putText(img_test, str(cnt), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
cv2.imwrite('experiment/target_'+str(IMG_NUM)+'.jpg', img_test)
plt.figure(figsize=(50,25))
img_test = cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB)
plt.imshow(img_test)
# Out:
# [[48, 1026, 1029, 165], [546, 1239, 450, 591], [1044, 1239, 450, 591], [48, 1239, 450, 591], [48, 1986, 1029, 102], [546, 2136, 450, 594], [48, 2136, 450, 594], [1044, 2136, 450, 594], [1037, 1233, 88, 587], [542, 1725, 455, 101], [1037, 1233, 88, 587], [542, 1725, 455, 101], [6, 2190, 363, 144], [381, 2190, 363, 144], [756, 2190, 363, 144], [813, 2025, 162, 162], [975, 2025, 132, 162], [1037, 1233, 88, 587], [542, 1725, 455, 101], [1037, 1233, 88, 587], [542, 1725, 455, 101]]
# [[[229, [232, 227, 230, -1]], [47, 237, 147, 78], ['Fe', 74]], [[227, [229, 224, 228, -1]], [1005, 243, 72, 72], ['202', 59]], [[224, [227, 214, 225, -1]], [874, 244, 72, 70], [')', 59]], [[214, [224, 204, 215, -1]], [41, 371, 517, 181], ["JoJo'sBizarre Playlist:Battl...", 92]], [[204, [214, 203, 205, -1]], [567, 372, 516, 181], ['nt集體制中', 68]], [[191, [202, 183, 192, -1]], [42, 564, 516, 181], ['LIAM GALLAGHER....', 79]], [[183, [191, 162, 184, -1]], [567, 564, 516, 181], ['ReleaseRadar', 95]], [[162, [183, 151, 163, -1]], [42, 756, 515, 180], ['落日飛車', 94]], [[151, [162, 141, 152, -1]], [567, 756, 516, 180], ['Jubilee', 96]], [[137, [139, 98, 138, -1]], [43, 1032, 556, 154], ['Oasis', 96]], [[98, [137, 66, 99, -1]], [42, 1233, 462, 462], ['fPeaAa.', 52]], [[66, [98, 57, 67, -1]], [540, 1233, 463, 462], ['BestofRock 1995 加、', 68]], [[73, [75, 72, 74, 66]], [786, 1588, 198, 96], ['‘', 37]], [[57, [66, 56, 58, -1]], [1037, 1233, 88, 324], [',', 1]], [[35, [36, 34, -1, -1]], [542, 1634, 583, 192], ['The Peppers,', 96]], [[37, [38, 36, -1, -1]], [43, 1725, 440, 95], ['Snow', 96]], [[17, [18, 15, -1, -1]], [194, 2057, 230, 48], ['Stand By Me', 96]], [[15, [17, 13, 16, -1]], [855, 2073, 78, 63], ['L[6]', 71]], [[13, [15, 11, 14, -1]], [1017, 2075, 57, 62], ['>', 93]], [[11, [13, 9, 12, -1]], [194, 2113, 104, 40], ['Oasis', 96]], [[3, [4, 2, -1, -1]], [525, 2202, 74, 129], ['搜尋', 96]], [[4, [5, 3, -1, -1]], [150, 2203, 74, 128], ['首頁', 96]], [[2, [3, 0, -1, -1]], [851, 2208, 173, 123], ['你的音樂庫', 94]]]

# %%
# %%time

tp=0
fp=0
fn=0
tn=0

for i in range(0,width+1):
    for j in range(0,height+1):
        for c in contourInfo:
            flag_b = 0 ##用來判斷有沒有在c裡，有的話會變1
            if i in range(c[1][0], c[1][0]+c[1][2]+1) and j in range(c[1][1], c[1][1]+c[1][3]+1):
                ##(i,j)在c裡
                flag_a = 0 ##用來判斷在c裡的有沒有在d裡，有的話會變1
                flag_b = 1
                for d in dictInfo:
                    if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
                        ##(i,j)在c裡且在d裡
                        ##true positive
                        tp+=1
                        flag_a = 1
                        #print([i,j],': tp')
                        break
                if flag_a ==0:
                    ##(i,j)在c裡但不在任何d裡
                    ##false positive
                    fp+=1
                    #print([i,j],': fp')
                    break
                else: break
                    
            if flag_b == 0:
                flag_c = 0 ##用來判斷不在c裡的有沒有在d裡，有的話會變1
                for d in dictInfo:
                    if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
                        ##(i,j)不在任何c裡但是在d裡
                        ##false negative
                        fn+=1
                        flag_c = 1
                        #print([i,j],': fn')
                        break
                if flag_c ==0:
                    ##(i,j)不在任何c裡也不在任何d裡 
                    ##true negative
                    tn+=1
                    #print([i,j],': tn')
                    break
                else: break

                
print(tp,fp,fn,tn)
# Out:
# 34900 5060 2187852 516250
# CPU times: user 28.4 s, sys: 129 ms, total: 28.6 s
# Wall time: 29.8 s

# %%
print(tp,fp,fn,tn)
print(img.size)
# Out:
# 14400 0 1441993 1287669
# 8221500

# %%
# %%time
##facebook:(tp,fp,fn,tn) = (14400 0 1441993 1287669)
##instagram:(tp,fp,fn,tn)=34900 5060 2187852 516250

# a=[(x,y) for x in range(width+1) for y in range(height+1)]
# a=[(x,y) for x in range(5+1) for y in range(5+1)]
# print(len(a))
# NUM_THREADS = os.cpu_count()
# NUM_THREADS = 8
# print('Logical Processors: ',NUM_THREADS)

# tp=0
# fp=0
# fn=0
# tn=0

# def checkPixel(pixel,contourInfo,dictInfo):
#     for c in contourInfo:
#         flag_b = 0 ##用來判斷有沒有在c裡，有的話會變1
#         if i in range(c[1][0], c[1][0]+c[1][2]+1) and j in range(c[1][1], c[1][1]+c[1][3]+1):
#             ##(i,j)在c裡
#             flag_a = 0 ##用來判斷在c裡的有沒有在d裡，有的話會變1
#             flag_b = 1
#             for d in dictInfo:
#                 if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
#                     ##(i,j)在c裡且在d裡
#                     ##true positive
#                     tp+=1
#                     flag_a = 1
#                     print([i,j],': tp',tp)
#                     break
#             if flag_a ==0:
#                 ##(i,j)在c裡但不在任何d裡
#                 ##false positive
#                 fp+=1
#                 print([i,j],': fp',fp)
#                 break
#             else: break

#         if flag_b == 0:
#             flag_c = 0 ##用來判斷不在c裡的有沒有在d裡，有的話會變1
#             for d in dictInfo:
#                 if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
#                     ##(i,j)不在任何c裡但是在d裡
#                     ##false negative
#                     fn+=1
#                     flag_c = 1
#                     print([i,j],': fn',fn)
#                     break
#             if flag_c ==0:
#                 ##(i,j)不在任何c裡也不在任何d裡 
#                 ##true negative
#                 tn+=1
#                 print([i,j],': tn',tn)
#                 break
#             else: break
# with concurrent.futures.ThreadPoolExecutor(NUM_THREADS) as executor:
#     futures = {executor.submit(checkPixel, pixel,contourInfo, dictInfo): pixel for pixel in a}
#     concurrent.futures.wait(futures)
# Out:
# 36
# Logical Processors:  8
# CPU times: user 4.92 ms, sys: 9.95 ms, total: 14.9 ms
# Wall time: 21.1 ms
