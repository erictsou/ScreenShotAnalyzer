# %%
import cv2
import numpy as np
from  matplotlib import pyplot as plt
from imp import reload 
import sys
import os
import concurrent.futures

# %%
def getDictInfo(element, img_test, test_tag, cnt, dictInfo):
    if (True in (element['tag'] == a for a in test_tag)) or (True in (a in element['tag'] for a in test_tag)):
        x = int(element['x'])
        y = int(element['y'])
        w = int(element['width'])
        h = int(element['height'])
        dictInfo.append([x,y,w,h])
        cv2.rectangle(img_test, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(img_test, str(cnt), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
        
def analyzeDict(img, test_tag):
    dictInfo=[]
    img_test = img.copy()
    ##94 elements
    cnt = 0
    for i in hierarchy_dict:
        cnt+=1
        print('i:',i["tag"], cnt)
        if "_EA@text" in i: print(i["_EA@text"], cnt)
        getDictInfo(i, img_test, test_tag, cnt, dictInfo)

        for j in i['child']:
            cnt+=1
            print('j:',j["tag"], cnt)
            if "_EA@text" in j: print(j["_EA@text"], cnt)
            getDictInfo(j, img_test, test_tag, cnt, dictInfo)

            for k in j['child']:
                cnt+=1
                print('k:',k["tag"], cnt)
                if "_EA@text" in k: print(k["_EA@text"], cnt)
                getDictInfo(k, img_test, test_tag, cnt, dictInfo)

                for l in k['child']:
                    cnt+=1
                    print('l:',l["tag"], cnt)
                    if "_EA@text" in l: print(l["_EA@text"], cnt)
                    getDictInfo(l, img_test, test_tag, cnt, dictInfo)

                    for m in l['child']:
                        cnt+=1
                        print('m:',m["tag"], cnt)
                        if "_EA@text" in m: print(m["_EA@text"], cnt)
                        getDictInfo(m, img_test, test_tag, cnt, dictInfo)

                        for n in m['child']:
                            cnt+=1
                            print('n:',n["tag"], cnt)
                            if "_EA@text" in n: print(n["_EA@text"], cnt)
                            getDictInfo(n, img_test, test_tag, cnt, dictInfo)

                            for o in n['child']:
                                cnt+=1
                                print('o:',o["tag"], cnt)
                                if "_EA@text" in o: print(o["_EA@text"], cnt)
                                getDictInfo(o, img_test, test_tag, cnt, dictInfo)



    print('total element num:', cnt)
    cv2.imwrite('experiment/target_'+str(IMG_NUM)+'.jpg', img_test)
    plt.figure(figsize=(50,25))
    img_test = cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB)
    plt.imshow(img_test)
    return dictInfo

# %%
##analyze taad dumped dict and experiment
import json
from allProcess import *
reload(sys.modules['allProcess'])
from allProcess import *

IMG_LIST = [1]
IMG_NUM = 1


# print('===========PROCESSING IMAGE NUMBER '+str(IMG_NUM)+'=============')

    
#with open('./experiment/'+str(IMG_NUM)+'.json', 'r') as fp:
with open('./experiment/data.json', 'r') as fp:
    j = json.load(fp)
hierarchy_dict = j['child']

img = cv2.imread('./experiment/'+str(IMG_NUM)+'.png', 1)
height,width,_ = img.shape
print('shape:', height,width)
test_tag=['button','img']


dictInfo = analyzeDict(img, test_tag)
contours = allProcess(str(IMG_NUM), True)
#implement experiment設為true
contourInfo = [c for c in contours if c[1][1]+c[1][3]>92]
##刪掉時間和電池圖示
# Out:
# shape: 2436 1125
# i: div 1
# j: div 2
# k: button 3
# Instagram 主要動態消息 3
# k: button 4
# 悄悄傳訊息 4
# k: button 5
# 最新動態 5
# j: ul 6
# k: button 7
# 限時動態匣 7
# k: ['div', 'button'] 8
# k: ['div', 'button'] 9
# k: div 10
# l: button 11
# 傳送 11
# l: button 12
# 儲存 12
# l: button 13
# 回應 13
# l: button 14
# 讚 14
# k: div 15
# l: div 16
# m: div 17
# afuuuuuuuuuu 17
# m: div 18
# lanyimingyoyo 18
# m: div 19
# leehongggg 19
# l: div 20
# m: button 21
# leehongggg 21
# m: button 22
# leehongggg和其他8,350人都說讚 22
# k: div 23
# l: div 24
# howhowhasfriends 疫情下的我們就像籠中鳥 都是四個字… 更多 24
# l: button 25
# howhowhasfriends 25
# l: button 26
# 更多 26
# k: ['button', 'div'] 27
# 查看全部59則留言 27
# k: div 28
# l: div 29
# m: div 30
# lanyimingyoyo 雖然身處不同的地方，看的是同一片天空 30
# m: button 31
# lanyimingyoyo 31
# l: button 32
# 對留言按讚 32
# k: div 33
# l: div 34
# m: div 35
# howhowhasfriends @lanyimingyoyo 國外的天空不知道會不會也比較圓 35
# m: button 36
# howhowhasfriends 36
# m: button 37
# @lanyimingyoyo 37
# l: button 38
# 對留言按讚 38
# k: div 39
# 水平捲軸, 1頁 39
# i: div 40
# j: button 41
# j: button 42
# 主要動態消息 42
# j: button 43
# 探索 43
# j: button 44
# 開啟相機 44
# j: button 45
# 購物 45
# j: button 46
# 個人檔案 46
# total element num: 46
# image size:  2436 * 1125
# lowThreshold, highThreshold, mean: 7 14 70.38493559569422
# canny mean: 8.583371647509578
# canny mean after dilate by 5 : 68.56406130268199
# number of contour result: 374
# number of contours after filted by hierarchy: 60
# number of contours after filted by size: 58
# number of contours after filted out img noises: 38
# Logical Processors:  8
# round[0]Box[0]thread[0]: x=73, y=2222, w=77, h=76, confidence: 94, text: Around[0]Box[0]thread[2]: x=299, y=2222, w=76, h=76, confidence: 92, text: Q [2, [4, 0, 3, -1]]
#  round[0]Box[0]thread[3]: x=523, y=2221, w=77, h=77, confidence: 89, text: (+)[4, [6, 2, 5, -1]]
#  [6, [11, 4, 7, -1]]
# get text thicker
# round[0]Box[0]thread[4]: x=972, y=2220, w=80, h=80, confidence: 48, text: © [11, [15, 6, 12, -1]]
# get text thinnerround[0]Box[0]thread[7]: x=688, y=2039, w=179, h=50, confidence: 90, text: 人都說讚
# round[0]Box[0]thread[3]: x=750, y=2219, w=74, h=79, confidence: 64, text: 台  [15, [18, 11, 16, -1]]
# [24, [25, 20, -1, -1]]
# round[0]Box[0]thread[4]: x=280, y=1928, w=76, h=69, confidence: 79, text: V [30, [31, 28, -1, -1]]
# round[0]Box[0]thread[4]: x=161, y=1925, w=74, h=74, confidence: 92, text: Q [35, [37, 33, 36, -1]]
# get text thinner
# round[0]Box[0]thread[7]: x=1014, y=1926, w=65, h=71, confidence: 76, text: A [33, [35, 31, 34, -1]]
# get text thicker
# round[0]Box[0]thread[7]: x=1033, y=674, w=52, h=20, confidence: 0, text:  [290, [291, 65, -1, -1]]
# round[0]Box[0]thread[6]: x=43, y=2117, w=387, h=43, confidence: 87, text: howhowhasfriends [19, [20, 18, -1, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=38, y=1927, w=80, h=71, confidence: 80, text: (2 [31, [33, 30, 32, -1]]
# round[0]Box[0]thread[3]: x=1067, y=537, w=58, h=31, confidence: 95, text: roc [297, [298, 296, -1, -1]]
# round[0]Box[0]thread[6]: x=25, y=631, w=106, h=106, confidence: 82, text: @ [292, [296, 291, 293, -1]]
# round[0]Box[0]thread[2]: x=193, y=2039, w=494, h=54, confidence: 72, text: leehonggggfUHitt8,361 [25, [28, 24, 26, -1]]
# round[0]Box[0]thread[3]: x=798, y=529, w=230, h=44, confidence: 92, text: cschen_1006 [298, [299, 297, -1, -1]]
# round[0]Box[0]thread[2]: x=309, y=529, w=167, h=45, confidence: 91, text: ivyhsu.twround[0]Box[0]thread[6]: x=531, y=529, w=240, h=45, confidence: 90, text: takayama.ka...  [299, [300, 298, -1, -1]]
# [300, [301, 299, -1, -1]]
# get text thicker
# round[0]Box[0]thread[5]: x=40, y=2032, w=142, h=65, confidence: 52, text: Pwd [28, [30, 25, 29, -1]]
# get text thicker
# round[0]Box[0]thread[6]: x=165, y=436, w=52, h=52, confidence: 96, text: + [306, [308, 305, 307, 302]]
# round[0]Box[0]thread[3]: x=54, y=526, w=153, h=46, confidence: 95, text: 限時動態 [301, [302, 300, -1, -1]]
# get text thinner
# round[0]Box[0]thread[2]: x=30, y=300, w=202, h=203, confidence: 53, text: (5 [302, [320, 301, 303, -1]]
# round[0]Box[0]thread[7]: x=154, y=661, w=387, h=43, confidence: 87, text: howhowhasfriends [291, [292, 290, -1, -1]]
# round[0]Box[0]thread[0]: x=433, y=2114, w=477, h=50, confidence: 77, text: 疫情下的我們就像籠中鳥get text thicker
# round[0]Box[0]thread[3]: x=536, y=286, w=233, h=232, confidence: 79, text: © [324, [336, 321, 325, -1]]
# [20, [24, 19, 21, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=1058, y=298, w=67, h=208, confidence: 90, text: ( [320, [321, 302, -1, -1]]
# round[0]Box[0]thread[3]: x=943, y=51, w=56, h=38, confidence: 95, text: 4G [365, [366, 358, -1, -1]]
# get text thinner
# round[0]Box[0]thread[7]: x=845, y=165, w=80, h=71, confidence: 80, text: (2 [347, [349, 336, 348, -1]]
# get text thicker
# round[0]Box[0]thread[4]: x=877, y=48, w=62, h=42, confidence: 0, text:  [367, [368, 366, -1, -1]]
# get text thinner
# round[0]Box[0]thread[0]: x=994, y=162, w=76, h=76, confidence: 78, text: 0 [349, [358, 347, 350, -1]]
# round[0]Box[0]thread[7]: x=54, y=47, w=133, h=44, confidence: 95, text: 22:49 [368, [371, 367, 369, -1]]
# get text thinner
# round[0]Box[0]thread[3]: x=189, y=49, w=40, h=40, confidence: 86, text: 子 [366, [367, 365, -1, -1]]
# get text thinner
# round[0]Box[0]thread[0]: x=1003, y=46, w=85, h=46, confidence: 30, text: 155! [371, [-1, 368, 372, -1]]
# get text thinner
# round[0]Box[0]thread[5]: x=52, y=154, w=359, h=110, confidence: 79, text: Instagram [358, [365, 349, 359, -1]]
# get text thicker
# round[0]Box[0]thread[3]: x=0, y=757, w=1125, h=1139, confidence: 86, text: / [65, [290, 64, 66, -1]]
# get text thicker
# round[0]Box[0]thread[1]: x=275, y=286, w=233, h=232, confidence: 67, text: @ [336, [347, 324, 337, -1]]
# get text thinner
# round[0]Box[0]thread[4]: x=797, y=286, w=233, h=232, confidence: 31, text: feoe oe 人 [321, [324, 320, 322, -1]]
# get text thinner
# round[0]Box[0]thread[2]: x=357, y=2391, w=412, h=26, confidence: 25, text: CY [0, [2, -1, 1, -1]]
# took tot: 3.731226921081543
# 9 [[302, [320, 301, 303, -1]], [30, 300, 202, 203], ['+', 96]]
# 10 [[301, [302, 300, -1, -1]], [54, 526, 153, 46], ['限時動態', 95]]
# before combine:  38
# after combine1:  24
# after combine2:  19
# after combine3:  18
# 18
# 367 [368, 366, -1, -1] [877, 46, 211, 46]
# text:  ['4G', 95]
# 366 [367, 365, -1, -1] [54, 47, 175, 44]
# text:  ['22:49', 95]
# 358 [365, 349, 359, -1] [52, 154, 359, 110]
# text:  ['Instagram', 79]
# 349 [358, 347, 350, -1] [994, 162, 76, 76]
# text:  ['0', 78]
# 347 [349, 336, 348, -1] [845, 165, 80, 71]
# text:  ['(2', 80]
# 301 [302, 300, -1, -1] [30, 286, 478, 288]
# text:  ['ivyhsu.tw +', 91]
# 320 [321, 302, -1, -1] [531, 286, 594, 288]
# text:  ['takayama.ka... (', 90]
# 297 [298, 296, -1, -1] [798, 529, 327, 44]
# text:  ['cschen_1006 roc', 92]
# 291 [292, 290, -1, -1] [25, 631, 516, 106]
# text:  ['howhowhasfriends', 87]
# 65 [290, 64, 66, -1] [0, 757, 1125, 1139]
# text:  ['/', 86]
# 30 [31, 28, -1, -1] [38, 1925, 829, 172]
# text:  ['Q 人都說讚', 92]
# 33 [35, 31, 34, -1] [1014, 1926, 65, 71]
# text:  ['A', 76]
# 19 [20, 18, -1, -1] [43, 2114, 867, 50]
# text:  ['howhowhasfriends', 87]
# 15 [18, 11, 16, -1] [750, 2219, 74, 79]
# 11 [15, 6, 12, -1] [972, 2220, 80, 80]
# 6 [11, 4, 7, -1] [523, 2221, 77, 77]
# text:  ['(+)', 89]
# 4 [6, 2, 5, -1] [73, 2222, 77, 76]
# text:  ['A', 94]
# 2 [4, 0, 3, -1] [299, 2222, 76, 76]
# text:  ['Q', 92]
# cnt:  18
# temp length:  18

# %%
print(dictInfo)
print(contourInfo)

clone = img.copy()
for i,c in enumerate(contourInfo):
    x,y,w,h = c[1]
    cv2.rectangle(clone, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(clone, str(c[0][0]), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
cv2.imwrite('experiment/processed_'+str(IMG_NUM)+'.jpg', clone)
plt.figure(figsize=(50,25))
clone = cv2.cvtColor(clone, cv2.COLOR_BGR2RGB)
plt.imshow(clone)
# Out:
# [[57, 159, 348, 99], [987, 153, 90, 93], [840, 153, 90, 93], [0, 282, 1125, 321], [0, 603, 1125, 162], [0, 765, 1125, 1125], [258, 1890, 120, 144], [987, 1890, 120, 144], [138, 1890, 120, 144], [18, 1890, 120, 144], [195, 2031, 246, 60], [195, 2040, 885, 60], [45, 2106, 384, 60], [303, 2160, 87, 60], [45, 2229, 363, 60], [45, 2298, 291, 60], [1005, 2298, 120, 111], [45, 2409, 384, 60], [435, 2409, 318, 60], [1005, 2409, 120, 111], [0, 2184, 1125, 3], [0, 2187, 225, 147], [225, 2187, 225, 147], [450, 2187, 225, 147], [675, 2187, 225, 147], [900, 2187, 225, 147]]
# [[[358, [365, 349, 359, -1]], [52, 154, 359, 110], ['Instagram', 79]], [[349, [358, 347, 350, -1]], [994, 162, 76, 76], ['0', 78]], [[347, [349, 336, 348, -1]], [845, 165, 80, 71], ['(2', 80]], [[301, [302, 300, -1, -1]], [30, 286, 478, 288], ['ivyhsu.tw +', 91]], [[320, [321, 302, -1, -1]], [531, 286, 594, 288], ['takayama.ka... (', 90]], [[297, [298, 296, -1, -1]], [798, 529, 327, 44], ['cschen_1006 roc', 92]], [[291, [292, 290, -1, -1]], [25, 631, 516, 106], ['howhowhasfriends', 87]], [[65, [290, 64, 66, -1]], [0, 757, 1125, 1139], ['/', 86]], [[30, [31, 28, -1, -1]], [38, 1925, 829, 172], ['Q 人都說讚', 92]], [[33, [35, 31, 34, -1]], [1014, 1926, 65, 71], ['A', 76]], [[19, [20, 18, -1, -1]], [43, 2114, 867, 50], ['howhowhasfriends', 87]], [[15, [18, 11, 16, -1]], [750, 2219, 74, 79], ['台', 64]], [[11, [15, 6, 12, -1]], [972, 2220, 80, 80], ['©', 48]], [[6, [11, 4, 7, -1]], [523, 2221, 77, 77], ['(+)', 89]], [[4, [6, 2, 5, -1]], [73, 2222, 77, 76], ['A', 94]], [[2, [4, 0, 3, -1]], [299, 2222, 76, 76], ['Q', 92]]]

# %%
# %%time

tp=0
fp=0
fn=0
tn=0

for i in range(0,width+1):
    for j in range(0,height+1):
        for c in contourInfo:
            flag_b = 0 ##用來判斷有沒有在c裡，有的話會變1
            if i in range(c[1][0], c[1][0]+c[1][2]+1) and j in range(c[1][1], c[1][1]+c[1][3]+1):
                ##(i,j)在c裡
                flag_a = 0 ##用來判斷在c裡的有沒有在d裡，有的話會變1
                flag_b = 1
                for d in dictInfo:
                    if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
                        ##(i,j)在c裡且在d裡
                        ##true positive
                        tp+=1
                        flag_a = 1
                        #print([i,j],': tp')
                        break
                if flag_a ==0:
                    ##(i,j)在c裡但不在任何d裡
                    ##false positive
                    fp+=1
                    #print([i,j],': fp')
                    break
                else: break
                    
            if flag_b == 0:
                flag_c = 0 ##用來判斷不在c裡的有沒有在d裡，有的話會變1
                for d in dictInfo:
                    if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
                        ##(i,j)不在任何c裡但是在d裡
                        ##false negative
                        fn+=1
                        flag_c = 1
                        #print([i,j],': fn')
                        break
                if flag_c ==0:
                    ##(i,j)不在任何c裡也不在任何d裡 
                    ##true negative
                    tn+=1
                    #print([i,j],': tn')
                    break
                else: break

                
print(tp,fp,fn,tn)
# Out:
# 34900 5060 2187852 516250
# CPU times: user 28.4 s, sys: 129 ms, total: 28.6 s
# Wall time: 29.8 s

# %%
print(tp,fp,fn,tn)
print(img.size)
# Out:
# 14400 0 1441993 1287669
# 8221500

# %%
# %%time
##facebook:(tp,fp,fn,tn) = (14400 0 1441993 1287669)
##instagram:(tp,fp,fn,tn)=34900 5060 2187852 516250

# a=[(x,y) for x in range(width+1) for y in range(height+1)]
# a=[(x,y) for x in range(5+1) for y in range(5+1)]
# print(len(a))
# NUM_THREADS = os.cpu_count()
# NUM_THREADS = 8
# print('Logical Processors: ',NUM_THREADS)

# tp=0
# fp=0
# fn=0
# tn=0

# def checkPixel(pixel,contourInfo,dictInfo):
#     for c in contourInfo:
#         flag_b = 0 ##用來判斷有沒有在c裡，有的話會變1
#         if i in range(c[1][0], c[1][0]+c[1][2]+1) and j in range(c[1][1], c[1][1]+c[1][3]+1):
#             ##(i,j)在c裡
#             flag_a = 0 ##用來判斷在c裡的有沒有在d裡，有的話會變1
#             flag_b = 1
#             for d in dictInfo:
#                 if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
#                     ##(i,j)在c裡且在d裡
#                     ##true positive
#                     tp+=1
#                     flag_a = 1
#                     print([i,j],': tp',tp)
#                     break
#             if flag_a ==0:
#                 ##(i,j)在c裡但不在任何d裡
#                 ##false positive
#                 fp+=1
#                 print([i,j],': fp',fp)
#                 break
#             else: break

#         if flag_b == 0:
#             flag_c = 0 ##用來判斷不在c裡的有沒有在d裡，有的話會變1
#             for d in dictInfo:
#                 if i in range(d[0], d[0]+d[2]+1) and j in range(d[1], d[1]+d[3]+1):
#                     ##(i,j)不在任何c裡但是在d裡
#                     ##false negative
#                     fn+=1
#                     flag_c = 1
#                     print([i,j],': fn',fn)
#                     break
#             if flag_c ==0:
#                 ##(i,j)不在任何c裡也不在任何d裡 
#                 ##true negative
#                 tn+=1
#                 print([i,j],': tn',tn)
#                 break
#             else: break
# with concurrent.futures.ThreadPoolExecutor(NUM_THREADS) as executor:
#     futures = {executor.submit(checkPixel, pixel,contourInfo, dictInfo): pixel for pixel in a}
#     concurrent.futures.wait(futures)
# Out:
# 36
# Logical Processors:  8
# CPU times: user 4.92 ms, sys: 9.95 ms, total: 14.9 ms
# Wall time: 21.1 ms
